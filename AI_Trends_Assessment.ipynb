# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing

# %%
df=pd.read_csv('/content/diabetic_data (1).csv')

# %%
df.head()

# %%
df.columns

# %%
df['readmitted']

# %%
df['readmitted'].isna().sum()

# %%
df.fillna(method='ffill', axis=1,inplace=True)

# %%
df['patient_nbr']

# %%
df.shape

# %%
df.describe()

# %%
df['weight']

# %%
df.drop(columns=['weight'],inplace=True)

# %%
df.isna().sum()

# %%
df.corr()

# %% [markdown]
# #Visualization

# %%
sns.pairplot(df)

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())

# %% [markdown]
# #1.no of patients not readmitted after treatment
# #2.no of patients readmitted within 30 days
# #3.no of patients readmitted after 30 days

# %%
grp1 = df.groupby(['patient_nbr','readmitted']).count()
grp1

# %%
# plot barplot
sns.barplot(x="patient_nbr",
           y="readmitted",
           hue="readmitted",
           data=df)

# %% [markdown]
# #4.range of ages which is affected by diabetics the most.
# #5.no.of males or females who are affected by diabetes more

# %%
grp2 = df.groupby(['age','diabetesMed']).count()
grp2

# %%
df.groupby(['age','diabetesMed']).size().plot(kind = "bar", color='red')

# %% [markdown]
# #5.no.of males or females who are affected by diabetes more

# %%
grp3 = df.groupby(['gender','diabetesMed']).count()
grp3

# %%
df.groupby(['gender','diabetesMed']).size().plot(kind = "bar", color=['purple','chocolate'])
